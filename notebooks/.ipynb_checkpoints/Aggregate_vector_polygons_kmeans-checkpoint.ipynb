# %%
# Import libraries
import geopandas as gpd
import matplotlib as mpl
import numpy as np

# %%
# For plot to appear in the notebook
# %matplotlib inline

# %% [markdown]
# # Import initial data

# %%
# Set the path to the original shapefile
admin1_shape="/media/tais/data/Dropbox/ULB/MAUPP/Coordination collaborateurs sur place/WP6_populeation_limitesadmin/Dakar_StLouis/Dakar_admin5_topological_clean/Dakar_units_core_cleaned.shp"

# %%
# Read the shapefile
gdf1 = gpd.read_file(admin1_shape)

# %%
# Add two columns to the attribute table with x (long) and y (lat)
gdf1["x"] = gdf1.centroid.map(lambda p: p.x)
gdf1["y"] = gdf1.centroid.map(lambda p: p.y)

# %%
# Display the attribute table
gdf1.head()
# Out:
#   Department Area4             Area5      Id_area5          Code Commune  \
# 0     PIKINE  MBAO  CITE NDEYE MARIE  1.230135e+11  1.230135e+11    Mbao
# 1     PIKINE  MBAO      NDOYENE SOUF  1.230135e+11  1.230135e+11    Mbao
# 2     PIKINE  MBAO          NDIOBENE  1.230135e+11  1.230135e+11    Mbao
# 3     PIKINE  MBAO            LAMSAR  1.230135e+11  1.230135e+11    Mbao
# 4     PIKINE  MBAO       NDOYENE KAW  1.230135e+11  1.230135e+11    Mbao
#
#            Quartier  CONCESSION  MENAGE  HOMME  FEMME  POPULATION  \
# 0  CITE NDEYE MARIE         310     343   1124   1142        2266
# 1      NDOYENE SOUF          55     124    545    575        1120
# 2          NDIOBENE          92     123    542    508        1050
# 3            LAMSAR          65     131    498    460         958
# 4       NDOYENE KAW         115     172    740    753        1493
#
#     Shape_Leng     Shape_Area  \
# 0  1455.303455  104294.145207
# 1  1091.641874   53131.494372
# 2  1215.072916   54988.418054
# 3   798.618709   32725.663230
# 4  1149.657763   73620.459691
#
#                                             geometry              x  \
# 0  POLYGON ((250391.4934 1629353.1556, 250319.658...  250415.671612
# 1  POLYGON ((249750.3291999996 1629808.9005, 2497...  249673.014011
# 2  POLYGON ((250113.2289000005 1629602.2348, 2501...  249951.172254
# 3  POLYGON ((250155.7130000005 1629917.0689, 2501...  249989.434381
# 4  POLYGON ((249878.8282000003 1630025.5766, 2498...  249696.999188
#
#                 y
# 0  1629636.035596
# 1  1629686.216988
# 2  1629563.238497
# 3  1629922.971439
# 4  1629965.857461

# %%
# A random colormap for matplotlib
cmap = mpl.colors.ListedColormap(np.random.rand(256,3))
# Display the shape
gdf1.plot(cmap=cmap, lw=0.2, figsize=(20,20))

# %% [markdown]
# # Kmeans clustering

# %%
# Getting the x/y values
f1 = gdf1['x'].values
f2 = gdf1['y'].values
X = np.array(list(zip(f1, f2)))

# Run Kmeans clustering
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=150).fit(X) # Here you can change the number of clusters you desire
labels = kmeans.predict(X) # Getting the cluster labels

# %%
# Joint results to the attribute table
gdf1["cluster"] = labels
# Display the attribute table
gdf1.head()
# Out:
#   Department Area4             Area5      Id_area5          Code Commune  \
# 0     PIKINE  MBAO  CITE NDEYE MARIE  1.230135e+11  1.230135e+11    Mbao
# 1     PIKINE  MBAO      NDOYENE SOUF  1.230135e+11  1.230135e+11    Mbao
# 2     PIKINE  MBAO          NDIOBENE  1.230135e+11  1.230135e+11    Mbao
# 3     PIKINE  MBAO            LAMSAR  1.230135e+11  1.230135e+11    Mbao
# 4     PIKINE  MBAO       NDOYENE KAW  1.230135e+11  1.230135e+11    Mbao
#
#            Quartier  CONCESSION  MENAGE  HOMME  FEMME  POPULATION  \
# 0  CITE NDEYE MARIE         310     343   1124   1142        2266
# 1      NDOYENE SOUF          55     124    545    575        1120
# 2          NDIOBENE          92     123    542    508        1050
# 3            LAMSAR          65     131    498    460         958
# 4       NDOYENE KAW         115     172    740    753        1493
#
#     Shape_Leng     Shape_Area  \
# 0  1455.303455  104294.145207
# 1  1091.641874   53131.494372
# 2  1215.072916   54988.418054
# 3   798.618709   32725.663230
# 4  1149.657763   73620.459691
#
#                                             geometry              x  \
# 0  POLYGON ((250391.4934 1629353.1556, 250319.658...  250415.671612
# 1  POLYGON ((249750.3291999996 1629808.9005, 2497...  249673.014011
# 2  POLYGON ((250113.2289000005 1629602.2348, 2501...  249951.172254
# 3  POLYGON ((250155.7130000005 1629917.0689, 2501...  249989.434381
# 4  POLYGON ((249878.8282000003 1630025.5766, 2498...  249696.999188
#
#                 y  cluster
# 0  1629636.035596        9
# 1  1629686.216988       24
# 2  1629563.238497       24
# 3  1629922.971439       24
# 4  1629965.857461       24

# %%
# A random colormap for matplotlib
cmap = mpl.colors.ListedColormap(np.random.rand(256,3))
# Display the shape
gdf1.plot(column='cluster', cmap=cmap, lw=0.2, figsize=(20, 20))  #Adapt the column according to your own data

# %% [markdown]
# # Dissolve admin1 level to get admin0 level

# %%
# Use dissolve function of Geopandas
gdf0 = gdf1.dissolve(by='cluster', aggfunc='sum')
# Drop columns that loose their mean by getting aggregated using 'sum' function
gdf0.drop(['Id_area5','Code', 'Shape_Leng', 'Shape_Area', 'x', 'y'], axis=1, inplace=True) #Adapt the column according to your own data
# Display the attribute table
gdf0.head()
# Out:
#                                                   geometry  CONCESSION  \
# cluster
# 0        POLYGON ((256254.6646999996 1635296.068600001,...        1063
# 1        POLYGON ((243148.8114 1630882.468599999, 24308...         816
# 2        POLYGON ((235954.0318 1629668.5195, 235923.256...        2851
# 3        POLYGON ((257281.0115999999 1627033.7359, 2573...        1841
# 4        POLYGON ((249434.1272999998 1635122.954399999,...        2935
#
#          MENAGE  HOMME  FEMME  POPULATION
# cluster
# 0          1271   5349   4947       10296
# 1          1849   7155   6777       13932
# 2          8218  21741  21749       43491
# 3          3024  13651  14027       27677
# 4          4067  16892  16713       33606

# %%
# Add count of admin1 unit in each cluster
count_units = gdf1.dissolve(by='cluster', aggfunc='count')['x']
gdf0['count'] = count_units
# Display the attribute table
gdf0.head()
# Out:
#                                                   geometry  CONCESSION  \
# cluster
# 0        POLYGON ((256254.6646999996 1635296.068600001,...        1063
# 1        POLYGON ((243148.8114 1630882.468599999, 24308...         816
# 2        POLYGON ((235954.0318 1629668.5195, 235923.256...        2851
# 3        POLYGON ((257281.0115999999 1627033.7359, 2573...        1841
# 4        POLYGON ((249434.1272999998 1635122.954399999,...        2935
#
#          MENAGE  HOMME  FEMME  POPULATION  count
# cluster
# 0          1271   5349   4947       10296      2
# 1          1849   7155   6777       13932      7
# 2          8218  21741  21749       43491     15
# 3          3024  13651  14027       27677     10
# 4          4067  16892  16713       33606     14

# %%
# A random colormap for matplotlib
cmap = mpl.colors.ListedColormap(np.random.rand(256,3))
# Display the shape
gdf0.plot(cmap=cmap, lw=0.2, figsize=(20, 20))  #Adapt the column according to your own data

# %% [markdown]
# ## Check if there is at least x original units in the newly created map

# %%
# Create a dictionnary with count of units in each cluster
cluster_list = list(gdf1['cluster'])
counter_dict = {i:cluster_list.count(i) for i in cluster_list}
# Check how many cluster are composed of only have one unit 
l=[]
[l.append(key) for key in counter_dict.keys() if counter_dict[key]<2]
if len(l)>0:
    print "There are %s cluster which only have one original unit."%len(l)
# Out:
# There are 18 cluster which only have one original unit.

# %%
gdf0["NEIGHBORS"] = None  # add NEIGHBORS column

for index, country in df.iterrows():   
    # get 'not disjoint' countries
    neighbors = df[~df.geometry.disjoint(country.geometry)].NAME.tolist()
    # remove own name from the list
    neighbors = [ name for name in neighbors if country.NAME != name ]
    # add names of neighbors as NEIGHBORS value
    df.at[index, "NEIGHBORS"] = ", ".join(neighbors)

# save GeoDataFrame as a new file
df.to_file("c:/path/to/newfile.shp")

# %%
# Display the attribute table
gdf0.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-8cc96a821d85> in <module>()
#       1 # Display the attribute table
# ----> 2 gdf0.head()
#
# NameError: name 'gdf0' is not defined

# %% [markdown]
# # Export admin1 shapefile

# %%
# Set the path to the shapefile to be created
shape_export = '/media/tais/My_Book_1/MAUPP/Traitement/Population_modelling_dasymetry/Results/Dakar/admin0.shp'
# Export
gdf0.to_file(driver='ESRI Shapefile',filename=shape_export)
